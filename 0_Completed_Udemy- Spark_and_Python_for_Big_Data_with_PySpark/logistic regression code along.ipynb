# %%
from pyspark.sql import SparkSession
from pyspark.ml.classification import LogisticRegression

spark = SparkSession.builder.appName("mylogreg").getOrCreate()

my_data = spark.read.format("libsvm").load("dbfs:/FileStore/shared_uploads/necmettinceylan@hotmail.com/sample_libsvm_data.txt")
my_data.show(
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------------------+
# label|            features|
# +-----+--------------------+
#   0.0|(692,[127,128,129...|
#   1.0|(692,[158,159,160...|
#   1.0|(692,[124,125,126...|
#   1.0|(692,[152,153,154...|
#   1.0|(692,[151,152,153...|
#   0.0|(692,[129,130,131...|
#   1.0|(692,[158,159,160...|
#   1.0|(692,[99,100,101,...|
#   0.0|(692,[154,155,156...|
#   0.0|(692,[127,128,129...|
#   1.0|(692,[154,155,156...|
#   0.0|(692,[153,154,155...|
#   0.0|(692,[151,152,153...|
#   1.0|(692,[129,130,131...|
#   0.0|(692,[154,155,156...|
#   1.0|(692,[150,151,152...|
#   0.0|(692,[124,125,126...|
#   0.0|(692,[152,153,154...|
# ...

# %%
my_log_reg_model = LogisticRegression(  )
fitted_logreg= my_log_reg_model.fit(my_data)
log_summary = fitted_logreg.summary
log_summary.predictions.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- label: double (nullable = true)
# -- features: vector (nullable = true)
# -- rawPrediction: vector (nullable = true)
# -- probability: vector (nullable = true)
# -- prediction: double (nullable = false)
#
# </div>

# %%
log_summary.predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------------------+--------------------+--------------------+----------+
# label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
#   0.0|(692,[127,128,129...|[19.8534775947478...|[0.99999999761359...|       0.0|
#   1.0|(692,[158,159,160...|[-20.377398194908...|[1.41321555111084...|       1.0|
#   1.0|(692,[124,125,126...|[-27.401459284890...|[1.25804865127067...|       1.0|
#   1.0|(692,[152,153,154...|[-18.862741612667...|[6.42710509170691...|       1.0|
# ...

# %%
lr_train, lr_test= my_data.randomSplit([0.7,0.3])
final_model = LogisticRegression()
fit_final = final_model.fit(lr_train)
prediction_and_labels= fit_final.evaluate(lr_test)
prediction_and_labels.predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------------------+--------------------+--------------------+----------+
# label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
#   0.0|(692,[98,99,100,1...|[25.6927232207559...|[0.99999999999305...|       0.0|
#   0.0|(692,[100,101,102...|[9.59246184582943...|[0.99993176344125...|       0.0|
#   0.0|(692,[123,124,125...|[30.0839645606894...|[0.99999999999991...|       0.0|
#   0.0|(692,[123,124,125...|[21.4397890517358...|[0.99999999951155...|       0.0|
# ...

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
myeval = BinaryClassificationEvaluator()
my_final_roc = myeval.evaluate(prediction_and_labels.predictions)
my_final_roc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 1.0</div>
