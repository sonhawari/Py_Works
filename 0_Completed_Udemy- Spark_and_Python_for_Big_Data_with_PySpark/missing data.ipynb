# %%
from pyspark.sql import SparkSession 

spark = SparkSession.builder.appName("miss").getOrCreate()

df = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/necmettinceylan@hotmail.com/ContainsNull.csv", inferSchema=True, header=True)
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp1| John| null|
# emp2| null| null|
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.drop( thresh=2 ).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp1| John| null|
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.drop( how="all" ).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp1| John| null|
# emp2| null| null|
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.drop( how="any" ).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.drop( subset=["sales"] ).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Id: string (nullable = true)
# -- Name: string (nullable = true)
# -- Sales: double (nullable = true)
#
# </div>

# %%
df.na.fill( "No name", subset=["name"] ).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+-----+
#   Id|   Name|Sales|
# +----+-------+-----+
# emp1|   John| null|
# emp2|No name| null|
# emp3|No name|345.0|
# emp4|  Cindy|456.0|
# +----+-------+-----+
#
# </div>

# %%
from pyspark.sql.functions import mean
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mean_val = df.select( mean( df["Sales"] ) ).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mean_sales = mean_val[0][0]
mean_sales
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: 400.5</div>

# %%
df.na.fill( mean_sales, ["Sales"] ).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp1| John|400.5|
# emp2| null|400.5|
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.fill(  df.select( mean(df["Sales"])).collect()[0][0], ["Sales"] ).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp1| John|400.5|
# emp2| null|400.5|
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>
