# %%
library(ggplot2)
library(forecast )
library(fpp2)
library(seasonal)
# Out:
# Warning message:
# "package 'fpp3' was built under R version 3.6.2"-- Attaching packages ---------------------------------------------- fpp3 0.1 --
# v tibble      2.1.3       v tsibble     0.8.5
# v dplyr       0.8.0.1     v tsibbledata 0.1.0
# v tidyr       0.8.3       v feasts      0.1.1
# v lubridate   1.7.4       v fable       0.1.1
# Warning message:
# "package 'tibble' was built under R version 3.6.2"Warning message:
# "package 'tsibble' was built under R version 3.6.2"
# Error: package or namespace load failed for 'fpp3':
#  .onAttach failed in attachNamespace() for 'fpp3', details:
#   call: NULL
#   error: package or namespace load failed for 'tsibble' in loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]]):
#  namespace 'dplyr' 0.8.0.1 is already loaded, but >= 0.8.1 is required
# Traceback:
#
# 1. library(fpp3)
# 2. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
#  .     env <- attachNamespace(ns, pos = pos, deps, exclude, include.only)
#  . }, error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste(" in", deparse(cc)[1L])
#  .     else ""
#  .     msg <- gettextf("package or namespace load failed for %s%s:\n %s",
#  .         sQuote(package), P, conditionMessage(e))
#  .     if (logical.return)
#  .         message(paste("Error:", msg), domain = NA)
#  .     else stop(msg, call. = FALSE, domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. value[[3L]](cond)
# 6. stop(msg, call. = FALSE, domain = NA)

# %%
library(fpp3)

# %% [markdown]
# # gold

# %%
help(gold)

# %%
tsdisplay(gold)
# Out:
# Plot with title ""

# %%
autoplot(gold)
# Out:
# plot without title

# %%
frequency(gold)
# Out:
# [1] 1

# %%
which.max(gold)
# Out:
# [1] 770

# %% [markdown]
# # woolyrnq

# %%
help(woolyrnq)

# %%
tsdisplay(woolyrnq)
# Out:
# Plot with title ""

# %%
autoplot(woolyrnq)
# Out:
# plot without title

# %%
frequency(woolyrnq)
# Out:
# [1] 4

# %%
which.max(woolyrnq)
# Out:
# [1] 21

# %%
which.min(woolyrnq)
# Out:
# [1] 41

# %% [markdown]
# # gas

# %%
help(gas)

# %%
plot(gas)
# Out:
# plot without title

# %%
seasonplot(gas)
# Out:
# Plot with title "Seasonal plot: gas"

# %%
tsdisplay(gas)
# Out:
# Plot with title ""

# %%
autoplot(gas)
# Out:
# plot without title

# %%
frequency(gas)
# Out:
# [1] 12

# %%
which.max(gas)
# Out:
# [1] 475

# %%
which.min(gas)
# Out:
# [1] 2

# %% [markdown]
# # 2.

# %%
tute1 <- read.csv("tute1.csv", header=TRUE)
tute1
# Out:
#     X      Sales  AdBudget GDP
# 1   Mar-81 1020.2 659.2    251.8
# 2   Jun-81  889.2 589.0    290.9
# 3   Sep-81  795.0 512.5    290.8
# 4   Dec-81 1003.9 614.1    292.4
# 5   Mar-82 1057.7 647.2    279.1
# 6   Jun-82  944.4 602.0    254.0
# 7   Sep-82  778.5 530.7    295.6
# 8   Dec-82  932.5 608.4    271.7
# 9   Mar-83  996.5 637.9    259.6
# 10  Jun-83  907.7 582.4    280.5
# 11  Sep-83  735.1 506.8    287.2
# 12  Dec-83  958.1 606.7    278.0
# 13  Mar-84 1034.1 658.7    256.8
# 14  Jun-84  992.8 614.9    271.0
# 15  Sep-84  791.7 489.9    300.9
# 16  Dec-84  914.2 586.5    289.8
# 17  Mar-85 1106.5 663.0    266.8
# 18  Jun-85  985.1 591.7    273.7
# 19  Sep-85  823.9 502.2    301.3
# 20  Dec-85 1025.1 616.4    285.6
# 21  Mar-86 1064.7 647.1    270.6
# 22  Jun-86  981.9 615.5    274.6
# 23  Sep-86  828.3 514.8    299.7
# 24  Dec-86  940.7 609.1    275.9
# 25  Mar-87  991.1 641.3    279.3
# 26  Jun-87 1021.2 620.2    290.8
# 27  Sep-87  796.7 511.2    295.6
# 28  Dec-87  986.6 621.3    271.9
# 29  Mar-88 1054.2 645.3    267.4
# 30  Jun-88 1018.7 616.0    281.0
# ... ...    ...    ...      ...
# 71  Sep-98  805.6 497.0    292.1
# 72  Dec-98  934.1 602.8    287.6
# 73  Mar-99 1081.7 647.3    258.0
# 74  Jun-99 1062.3 612.5    282.9
# 75  Sep-99  798.8 492.2    295.0
# 76  Dec-99 1014.3 610.8    271.2
# 77  Mar-00 1049.5 646.5    275.4
# 78  Jun-00  961.7 603.3    284.0
# 79  Sep-00  793.4 503.8    300.9
# 80  Dec-00  872.3 598.3    277.4
# 81  Mar-01 1014.2 649.4    273.8
# 82  Jun-01  952.6 620.2    288.4
# 83  Sep-01  792.4 497.9    283.4
# 84  Dec-01  922.3 609.2    273.4
# 85  Mar-02 1055.9 665.9    271.5
# 86  Jun-02  906.2 600.4    283.6
# 87  Sep-02  811.2 502.3    290.6
# 88  Dec-02 1005.8 605.6    289.1
# 89  Mar-03 1013.8 647.6    282.2
# 90  Jun-03  905.6 583.5    285.6
# 91  Sep-03  957.3 502.5    304.0
# 92  Dec-03 1059.5 625.9    271.5
# 93  Mar-04 1090.6 648.7    263.9
# 94  Jun-04  998.9 610.7    288.3
# 95  Sep-04  866.6 519.1    290.2
# 96  Dec-04 1018.7 634.9    284.0
# 97  Mar-05 1112.5 663.1    270.9
# 98  Jun-05  997.4 583.3    294.7
# 99  Sep-05  826.8 508.6    292.2
# 100 Dec-05  992.6 634.2    255.1

# %%
mytimeseries <- ts(tute1[,-1], start=1981, frequency=4)

# %%
mytimeseries
# Out:
# ERROR while rich displaying an object: Error in repr_matrix_generic(obj, "\n%s%s\n", sprintf("|%%s\n|%s|\n", : formal argument "cols" matched by multiple actual arguments
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_markdown.ts(obj)
# 9. repr_ts_generic(obj, repr_markdown.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
#         Sales  AdBudget GDP
# 1981 Q1 1020.2 659.2    251.8
# 1981 Q2  889.2 589.0    290.9
# 1981 Q3  795.0 512.5    290.8
# 1981 Q4 1003.9 614.1    292.4
# 1982 Q1 1057.7 647.2    279.1
# 1982 Q2  944.4 602.0    254.0
# 1982 Q3  778.5 530.7    295.6
# 1982 Q4  932.5 608.4    271.7
# 1983 Q1  996.5 637.9    259.6
# 1983 Q2  907.7 582.4    280.5
# 1983 Q3  735.1 506.8    287.2
# 1983 Q4  958.1 606.7    278.0
# 1984 Q1 1034.1 658.7    256.8
# 1984 Q2  992.8 614.9    271.0
# 1984 Q3  791.7 489.9    300.9
# 1984 Q4  914.2 586.5    289.8
# 1985 Q1 1106.5 663.0    266.8
# 1985 Q2  985.1 591.7    273.7
# 1985 Q3  823.9 502.2    301.3
# 1985 Q4 1025.1 616.4    285.6
# 1986 Q1 1064.7 647.1    270.6
# 1986 Q2  981.9 615.5    274.6
# 1986 Q3  828.3 514.8    299.7
# 1986 Q4  940.7 609.1    275.9
# 1987 Q1  991.1 641.3    279.3
# 1987 Q2 1021.2 620.2    290.8
# 1987 Q3  796.7 511.2    295.6
# 1987 Q4  986.6 621.3    271.9
# 1988 Q1 1054.2 645.3    267.4
# 1988 Q2 1018.7 616.0    281.0
# 1988 Q3  815.6 503.2    309.0
# 1988 Q4 1010.6 617.5    266.7
# 1989 Q1 1071.5 642.8    283.5
# 1989 Q2  954.0 585.6    282.3
# 1989 Q3  822.9 520.6    289.2
# 1989 Q4  867.5 608.6    270.7
# 1990 Q1 1002.3 645.7    266.5
# 1990 Q2  972.0 597.4    287.9
# 1990 Q3  782.9 499.8    287.6
# 1990 Q4  972.8 601.8    283.4
# 1991 Q1 1108.0 650.8    266.4
# 1991 Q2  943.7 588.3    292.3
# 1991 Q3  806.1 491.6    330.6
# 1991 Q4  954.2 603.3    286.2
# 1992 Q1 1115.5 663.2    259.2
# 1992 Q2  927.1 614.0    263.7
# 1992 Q3  800.7 506.3    288.2
# 1992 Q4  955.7 606.2    274.1
# 1993 Q1 1049.8 639.5    287.1
# 1993 Q2  886.0 585.9    285.5
# 1993 Q3  786.4 492.2    303.7
# 1993 Q4  991.3 610.4    275.6
# 1994 Q1 1113.9 660.8    249.3
# 1994 Q2  924.5 612.2    272.9
# 1994 Q3  771.4 509.2    289.8
# 1994 Q4  949.8 612.1    269.2
# 1995 Q1  990.5 653.2    261.3
# 1995 Q2 1071.4 605.3    292.9
# 1995 Q3  854.1 506.6    304.6
# 1995 Q4  929.8 597.4    276.3
# 1996 Q1  959.6 635.2    268.2
# 1996 Q2  991.1 611.6    293.5
# 1996 Q3  832.9 503.8    311.1
# 1996 Q4 1006.1 609.9    273.7
# 1997 Q1 1040.7 645.2    267.5
# 1997 Q2 1026.3 609.8    271.9
# 1997 Q3  785.9 512.1    308.8
# 1997 Q4  997.6 603.7    282.9
# 1998 Q1 1055.0 639.4    268.4
# 1998 Q2  925.6 601.6    271.4
# 1998 Q3  805.6 497.0    292.1
# 1998 Q4  934.1 602.8    287.6
# 1999 Q1 1081.7 647.3    258.0
# 1999 Q2 1062.3 612.5    282.9
# 1999 Q3  798.8 492.2    295.0
# 1999 Q4 1014.3 610.8    271.2
# 2000 Q1 1049.5 646.5    275.4
# 2000 Q2  961.7 603.3    284.0
# 2000 Q3  793.4 503.8    300.9
# 2000 Q4  872.3 598.3    277.4
# 2001 Q1 1014.2 649.4    273.8
# 2001 Q2  952.6 620.2    288.4
# 2001 Q3  792.4 497.9    283.4
# 2001 Q4  922.3 609.2    273.4
# 2002 Q1 1055.9 665.9    271.5
# 2002 Q2  906.2 600.4    283.6
# 2002 Q3  811.2 502.3    290.6
# 2002 Q4 1005.8 605.6    289.1
# 2003 Q1 1013.8 647.6    282.2
# 2003 Q2  905.6 583.5    285.6
# 2003 Q3  957.3 502.5    304.0
# 2003 Q4 1059.5 625.9    271.5
# 2004 Q1 1090.6 648.7    263.9
# 2004 Q2  998.9 610.7    288.3
# 2004 Q3  866.6 519.1    290.2
# 2004 Q4 1018.7 634.9    284.0
# 2005 Q1 1112.5 663.1    270.9
# 2005 Q2  997.4 583.3    294.7
# 2005 Q3  826.8 508.6    292.2
# 2005 Q4  992.6 634.2    255.1

# %%
autoplot(mytimeseries, facets=TRUE)
# Out:
# plot without title

# %%
autoplot(mytimeseries)
# Out:
# plot without title

# %% [markdown]
# # 3.

# %%
retaildata <- readxl::read_excel("retail.xlsx", skip=1)

# %%
myts <- ts(retaildata[,"A3349398A"],
  frequency=12, start=c(1982,4))

# %%
myts
# Out:
# ERROR while rich displaying an object: Error in repr_matrix_generic(obj, "\n%s%s\n", sprintf("|%%s\n|%s|\n", : formal argument "cols" matched by multiple actual arguments
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_markdown.ts(obj)
# 9. repr_ts_generic(obj, repr_markdown.matrix, ...)
# 10. repr_func(m, ..., rows = nrow(m), cols = ncol(m))
#      Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct
# 1982                       408.7  404.9  401.0  414.4  403.8  411.8  430.1
# 1983  420.3  428.8  460.0  429.0  422.6  430.6  434.2  448.2  440.6  462.1
# 1984  449.5  455.9  461.7  458.2  468.3  461.6  458.5  491.6  460.0  494.4
# 1985  503.3  466.5  494.0  487.0  517.4  487.9  549.9  532.9  514.6  558.1
# 1986  561.0  518.5  556.7  551.3  582.7  552.9  590.7  590.2  585.8  609.0
# 1987  617.1  571.5  592.8  604.2  608.2  587.1  615.9  617.8  615.0  643.0
# 1988  647.1  622.0  667.1  643.2  638.6  630.6  627.9  642.8  666.3  674.5
# 1989  665.7  652.8  750.5  717.2  718.0  722.0  727.5  753.1  768.5  751.9
# 1990  769.5  748.3  814.4  768.9  799.7  809.0  791.8  846.9  790.2  826.4
# 1991  875.8  796.9  868.1  816.5  866.9  807.1  849.1  913.5  828.2  899.4
# 1992  918.9  868.9  904.7  929.1  920.4  883.3  941.8  927.1  918.9  972.9
# 1993  946.3  902.1  949.8  962.1  951.8  922.3  953.3  925.6  943.3  979.8
# 1994  996.2  939.5 1031.5  968.7  979.3  983.4 1010.6 1020.1 1035.3 1063.2
# 1995 1047.1  995.3 1093.8 1077.2 1080.0 1075.6 1086.7 1138.7 1106.2 1163.1
# 1996 1145.9 1137.0 1182.3 1144.4 1202.7 1157.5 1176.0 1222.8 1163.8 1239.1
# 1997 1237.4 1141.2 1250.7 1189.1 1254.1 1167.8 1253.1 1268.4 1237.7 1331.9
# 1998 1373.6 1237.3 1311.9 1308.3 1320.5 1263.0 1311.6 1299.6 1302.9 1434.4
# 1999 1415.9 1292.3 1423.9 1361.8 1369.2 1331.5 1405.9 1376.0 1402.6 1463.5
# 2000 1412.7 1350.8 1429.8 1377.0 1369.8 1373.3 1375.4 1431.9 1429.7 1446.4
# 2001 1474.4 1373.2 1518.6 1499.6 1531.1 1491.1 1511.0 1572.2 1548.3 1640.4
# 2002 1709.3 1537.5 1692.4 1598.5 1678.8 1581.0 1663.0 1715.8 1659.2 1770.3
# 2003 1805.1 1632.1 1770.6 1708.1 1745.4 1623.3 1738.9 1742.9 1722.3 1852.3
# 2004 1908.2 1757.4 1841.5 1845.1 1829.8 1764.4 1871.5 1840.4 1858.9 1926.9
# 2005 1920.2 1781.3 1958.9 1875.7 1859.0 1833.4 1936.5 1955.6 1950.3 2038.8
# 2006 2044.0 1903.4 2101.4 2023.1 2007.0 1975.7 2027.6 2083.2 2065.5 2155.9
# 2007 2180.3 2025.8 2247.0 2148.4 2165.3 2094.9 2177.9 2261.2 2241.5 2335.1
# 2008 2304.5 2161.4 2332.6 2161.8 2259.1 2146.3 2207.4 2249.1 2152.6 2340.5
# 2009 2467.7 2174.9 2387.1 2333.6 2346.5 2243.0 2314.5 2359.5 2319.0 2498.0
# 2010 2542.6 2231.9 2469.8 2387.7 2426.5 2300.1 2441.2 2429.0 2411.6 2529.0
# 2011 2613.1 2365.2 2549.1 2502.8 2452.8 2395.4 2513.4 2531.5 2514.1 2630.8
# 2012 2591.3 2453.4 2633.9 2544.2 2569.2 2511.7 2545.4 2637.3 2585.1 2696.7
# 2013 2740.1 2479.7 2774.0 2607.6 2679.5 2575.2 2640.3 2756.6 2660.1 2808.4
#      Nov    Dec
# 1982  446.2  521.3
# 1983  474.5  566.1
# 1984  504.7  579.8
# 1985  565.0  649.8
# 1986  603.8  708.8
# 1987  639.2  759.2
# 1988  703.5  847.0
# 1989  789.3  983.0
# 1990  874.6  995.4
# 1991  908.5 1027.9
# 1992  928.9 1098.9
# 1993  978.9 1169.7
# 1994 1058.8 1267.6
# 1995 1201.9 1390.4
# 1996 1251.3 1382.7
# 1997 1314.5 1513.3
# 1998 1355.1 1585.0
# 1999 1430.1 1713.6
# 2000 1445.0 1698.2
# 2001 1663.2 1868.8
# 2002 1773.8 1972.3
# 2003 1838.0 2079.5
# 2004 1915.2 2241.3
# 2005 2024.6 2372.0
# 2006 2179.8 2511.5
# 2007 2386.4 2687.2
# 2008 2376.9 2752.6
# 2009 2623.4 2933.6
# 2010 2612.4 2991.9
# 2011 2613.0 3064.2
# 2012 2691.6 3102.2
# 2013 2775.1 3278.2

# %%
autoplot(myts)
# Out:
# plot without title

# %%
ggseasonplot(myts)
# Out:
# plot without title

# %%
ggsubseriesplot(myts)
# Out:
# plot without title

# %%
gglagplot(myts)
# Out:
# plot without title

# %%
ggAcf(myts)
# Out:
# plot without title

# %%
tsdisplay(myts)
# Out:
# Plot with title ""

# %% [markdown]
# # 4.

# %%
help(bicoal)

# %%
tsdisplay(bicoal)
# Out:
# Plot with title ""

# %%
help(chicken)

# %%
tsdisplay(chicken)
# Out:
# Plot with title ""

# %%
help(dole)

# %%
tsdisplay(dole)
# Out:
# Plot with title ""

# %%
help(usdeaths)

# %%
tsdisplay( usdeaths)
# Out:
# Plot with title ""

# %%
help(lynx)

# %%
tsdisplay(lynx)
# Out:
# Plot with title ""

# %%
help(goog)

# %%
tsdisplay(goog)
# Out:
# Plot with title ""

# %%
help(writing)

# %%
tsdisplay(writing)
# Out:
# Plot with title ""

# %%
help(fancy)

# %%
tsdisplay(fancy)
# Out:
# Plot with title ""

# %%
help(a10)

# %%
tsdisplay(a10)
# Out:
# Plot with title ""

# %%
help(h02)

# %%
tsdisplay(h02)
# Out:
# Plot with title ""

# %% [markdown]
# # 5.

# %%
ggseasonplot(writing)
# Out:
# plot without title

# %%
ggsubseriesplot(writing)
# Out:
# plot without title

# %%
ggseasonplot(fancy)
# Out:
# plot without title

# %%
ggsubseriesplot(fancy)
# Out:
# plot without title

# %%
ggseasonplot(a10)
# Out:
# plot without title

# %%
ggsubseriesplot(a10)
# Out:
# plot without title

# %%
ggseasonplot(h02)
# Out:
# plot without title

# %%
ggsubseriesplot(h02)
# Out:
# plot without title

# %%
help(h02)

# %% [markdown]
# # 6.

# %%
autoplot(hsales)
# Out:
# plot without title

# %%
ggseasonplot(hsales)
# Out:
# plot without title

# %%
ggsubseriesplot(hsales)
# Out:
# plot without title

# %%
gglagplot(hsales)
# Out:
# plot without title

# %%
ggAcf(hsales)
# Out:
# plot without title

# %%
tsdisplay(hsales)
# Out:
# Plot with title ""

# %%
autoplot(usdeaths)
# Out:
# plot without title

# %%
ggseasonplot(usdeaths)
# Out:
# plot without title

# %%
ggsubseriesplot(usdeaths)
# Out:
# plot without title

# %%
gglagplot(usdeaths)
# Out:
# plot without title

# %%
ggAcf(usdeaths)
# Out:
# plot without title

# %%
tsdisplay(usdeaths)
# Out:
# Plot with title ""

# %%
autoplot(bricksq)
# Out:
# plot without title

# %%
ggseasonplot(bricksq)
# Out:
# plot without title

# %%
ggsubseriesplot(bricksq)
# Out:
# plot without title

# %%
gglagplot(bricksq)
# Out:
# plot without title

# %%
ggAcf(bricksq)
# Out:
# plot without title

# %%
tsdisplay( bricksq)
# Out:
# Plot with title ""

# %%
autoplot(sunspotarea)
# Out:
# plot without title

# %%
ggseasonplot(sunspotarea)
# Out:
# Error in ggseasonplot(sunspotarea): Data are not seasonal
# Traceback:
#
# 1. ggseasonplot(sunspotarea)
# 2. stop("Data are not seasonal")

# %%
ggsubseriesplot(sunspotarea)
# Out:
# Error in ggsubseriesplot(sunspotarea): Data are not seasonal
# Traceback:
#
# 1. ggsubseriesplot(sunspotarea)
# 2. stop("Data are not seasonal")

# %%
gglagplot(sunspotarea)
# Out:
# plot without title

# %%
ggAcf(sunspotarea)
# Out:
# plot without title

# %%
tsdisplay(sunspotarea)
# Out:
# Plot with title ""

# %%
autoplot(gasoline)
# Out:
# plot without title

# %%
ggseasonplot(gasoline)
# Out:
# plot without title

# %%
ggsubseriesplot(gasoline)
# Out:
# Error in ggsubseriesplot(gasoline): Each season requires at least 2 observations. This may be caused from specifying a time-series with non-integer frequency.
# Traceback:
#
# 1. ggsubseriesplot(gasoline)
# 2. stop(paste("Each season requires at least 2 observations.", ifelse(frequency(x)%%1 ==
#  .     0, "Your series length may be too short for this graphic.",
#  .     "This may be caused from specifying a time-series with non-integer frequency.")))

# %%
gglagplot(gasoline)
# Out:
# plot without title

# %%
ggAcf(gasoline)
# Out:
# plot without title

# %%
tsdisplay( gasoline)
# Out:
# Plot with title ""

# %% [markdown]
# # 7.

# %%
autoplot(arrivals)
# Out:
# plot without title

# %%
ggseasonplot(arrivals)
# Out:
# Error in data.frame(y = as.numeric(x), year = trunc(round(time(x), 8)), : arguments imply differing number of rows: 508, 127
# Traceback:
#
# 1. ggseasonplot(arrivals)
# 2. data.frame(y = as.numeric(x), year = trunc(round(time(x), 8)),
#  .     cycle = as.numeric(cycle(x)), time = as.numeric((cycle(x) -
#  .         1)/s))
# 3. stop(gettextf("arguments imply differing number of rows: %s",
#  .     paste(unique(nrows), collapse = ", ")), domain = NA)

# %%
ggsubseriesplot(arrivals)
# Out:
# Error in data.frame(y = as.numeric(x), year = trunc(time(x)), season = as.numeric(phase)): arguments imply differing number of rows: 508, 127
# Traceback:
#
# 1. ggsubseriesplot(arrivals)
# 2. data.frame(y = as.numeric(x), year = trunc(time(x)), season = as.numeric(phase))
# 3. stop(gettextf("arguments imply differing number of rows: %s",
#  .     paste(unique(nrows), collapse = ", ")), domain = NA)

# %%
gg_season(arrivals)
# Out:
# Error in gg_season(arrivals): could not find function "gg_season"
# Traceback:

# %%
gg_subseries(arrivals)
# Out:
# Error in gg_subseries(arrivals): could not find function "gg_subseries"
# Traceback:

# %%
airpassengers
# Out:
# Error in eval(expr, envir, enclos): object 'airpassengers' not found
# Traceback:

# %% [markdown]
# # 9

# %%
mypigs <- window(pigs, start=1990)

# %%
autoplot(mypigs)
# Out:
# plot without title

# %%
ggAcf(mypigs)
# Out:
# plot without title

# %% [markdown]
# # 10.

# %%
ddj <- diff(dj)

# %%
tsdisplay(ddj)
# Out:
# Plot with title ""
