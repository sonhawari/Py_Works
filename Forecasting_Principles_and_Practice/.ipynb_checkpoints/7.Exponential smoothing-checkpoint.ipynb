# %%
library(ggplot2)
library(forecast )
library(fpp2)
library(seasonal)

# %%
oildata <- window(oil, start=1996)
autoplot(oildata) +
  ylab("Oil (millions of tonnes)") + xlab("Year")
# Out:
# plot without title

# %% [markdown]
# ## Component form
