# %%
library(ggplot2)
library(forecast )
library(fpp2)
library(seasonal)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.6.2"Warning message:
# "package 'forecast' was built under R version 3.6.2"Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# Registered S3 methods overwritten by 'forecast':
#   method             from
#   fitted.fracdiff    fracdiff
#   residuals.fracdiff fracdiff
# Warning message:
# "package 'fpp2' was built under R version 3.6.2"Loading required package: fma
# Warning message:
# "package 'fma' was built under R version 3.6.2"Loading required package: expsmooth
# Warning message:
# "package 'expsmooth' was built under R version 3.6.2"Warning message:
# "package 'seasonal' was built under R version 3.6.2"

# %% [markdown]
# Box-Cox transformation used for stabilising the variance

# %%
tsdisplay(usnetelec )
# Out:
# Plot with title ""

# %%
(lambda <- BoxCox.lambda(usnetelec))
#> [1] 0.2654
autoplot(BoxCox(usnetelec,lambda))
# Out:
# [1] 0.5167714
# plot without title

# %%
tsdisplay(BoxCox(usnetelec,lambda))
# Out:
# Plot with title ""

# %%
tsdisplay(usgdp)
# Out:
# Plot with title ""

# %%
(lambda <- BoxCox.lambda(usgdp))
#> [1] 0.2654
autoplot(BoxCox(usgdp,lambda))
# Out:
# [1] 0.366352
# plot without title

# %%
tsdisplay(mcopper)
# Out:
# Plot with title ""

# %%
(lambda <- BoxCox.lambda(mcopper))
#> [1] 0.2654
autoplot(BoxCox(mcopper,lambda))
# Out:
# [1] 0.1919047
# plot without title

# %%
tsdisplay(enplanements)
# Out:
# Plot with title ""

# %%
(lambda <- BoxCox.lambda(enplanements))
#> [1] 0.2654
autoplot(BoxCox(enplanements,lambda))
# Out:
# [1] -0.2269461
# plot without title

# %%
tsdisplay(cangas)
# Out:
# Plot with title ""

# %%
(lambda <- BoxCox.lambda(cangas ))
#> [1] 0.2654
autoplot(BoxCox(cangas ,lambda))
# Out:
# [1] 0.5767759
# plot without title

# %% [markdown]
# # 3.

# %%
retaildata <- readxl::read_excel("retail.xlsx", skip=1)

# %%
myts <- ts(retaildata[,"A3349398A"],
  frequency=12, start=c(1982,4))

# %%
myts
# Out:
# ERROR while rich displaying an object: Error in repr_matrix_generic(obj, "\n%s%s\n", sprintf("|%%s\n|%s|\n", : formal argument "cols" matched by multiple actual arguments
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
# ...

# %%
tsdisplay(myts)
# Out:
# Plot with title ""

# %%
(lambda <- BoxCox.lambda(myts ))
#> [1] 0.2654
autoplot(BoxCox(myts ,lambda))
# Out:
# [1] 0.1231563
# plot without title

# %% [markdown]
# # 4.

# %%
tsdisplay(dole)
# Out:
# Plot with title ""

# %%
(lambda <- BoxCox.lambda(dole ))
#> [1] 0.2654
autoplot(BoxCox(dole ,lambda))
# Out:
# [1] 0.3290922
# plot without title

# %%
tsdisplay(usdeaths)
# Out:
# Plot with title ""

# %%
(lambda <- BoxCox.lambda(usdeaths ))
#> [1] 0.2654
autoplot(BoxCox(usdeaths ,lambda))
# Out:
# [1] -0.03363775
# plot without title

# %%
tsdisplay(bricksq)
# Out:
# Plot with title ""

# %%
(lambda <- BoxCox.lambda(bricksq ))
#> [1] 0.2654
autoplot(BoxCox(bricksq ,lambda))
# Out:
# [1] 0.2548929
# plot without title

# %% [markdown]
# # 5.

# %%
beer <- window(ausbeer, start=1992)
fc <- snaive(beer)
autoplot(fc)
res <- residuals(fc)
autoplot(res)
# Out:
# plot without title
# plot without title

# %%
checkresiduals(fc)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Seasonal naive method
# Q* = 32.269, df = 8, p-value = 8.336e-05
#
# Model df: 0.   Total lags used: 8
# plot without title

# %%
beer <- window(ausbeer, start=1992)

# %%
tsdisplay(beer)
# Out:
# Plot with title ""

# %%
beer <- window(ausbeer, start=1992)
fc <- snaive(beer, h=8)
autoplot(fc)
# Out:
# plot without title

# %%
fc
# Out:
#         Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# 2010 Q3            419 398.3220 439.6780 387.3757 450.6243
# 2010 Q4            488 467.3220 508.6780 456.3757 519.6243
# 2011 Q1            414 393.3220 434.6780 382.3757 445.6243
# 2011 Q2            374 353.3220 394.6780 342.3757 405.6243
# 2011 Q3            419 389.7569 448.2431 374.2765 463.7235
# 2011 Q4            488 458.7569 517.2431 443.2765 532.7235
# 2012 Q1            414 384.7569 443.2431 369.2765 458.7235
# 2012 Q2            374 344.7569 403.2431 329.2765 418.7235

# %%
beer <- window(ausbeer, start=1992)
fc <- snaive(beer)
autoplot(fc)
res <- residuals(fc)
autoplot(res)
# Out:
# plot without title
# plot without title

# %%
fc
# Out:
#         Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# 2010 Q3            419 398.3220 439.6780 387.3757 450.6243
# 2010 Q4            488 467.3220 508.6780 456.3757 519.6243
# 2011 Q1            414 393.3220 434.6780 382.3757 445.6243
# 2011 Q2            374 353.3220 394.6780 342.3757 405.6243
# 2011 Q3            419 389.7569 448.2431 374.2765 463.7235
# 2011 Q4            488 458.7569 517.2431 443.2765 532.7235
# 2012 Q1            414 384.7569 443.2431 369.2765 458.7235
# 2012 Q2            374 344.7569 403.2431 329.2765 418.7235

# %%
checkresiduals(fc)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Seasonal naive method
# Q* = 32.269, df = 8, p-value = 8.336e-05
#
# Model df: 0.   Total lags used: 8
# plot without title

# %% [markdown]
# # 6.

# %%
autoplot(WWWusage)
# Out:
# plot without title

# %%
autoplot(naive(WWWusage, 12) )
# Out:
# plot without title

# %%
autoplot( rwf(WWWusage, 12, drift=TRUE) )
# Out:
# plot without title

# %%
autoplot( snaive( WWWusage, 12, drift=TRUE ) )
# Out:
# plot without title

# %%
tsdisplay(WWWusage)
# Out:
# Plot with title ""

# %%
autoplot(bricksq)
# Out:
# plot without title

# %%
gg <- snaive(bricksq, 12, drift= FALSE) 
autoplot( gg)
# Out:
# plot without title

# %%
zz  <- rwf(bricksq, 12, drift=FALSE)
zzres <- residuals(zz)
autoplot( zz )
# Out:
# plot without title

# %%
autoplot(zzres)
# Out:
# plot without title

# %%
mean(zzres, na.rm=TRUE)
# Out:
# [1] 1.980519

# %%
tsdisplay(zzres)
# Out:
# Plot with title ""

# %%
tsdisplay(bricksq)
# Out:
# Plot with title ""

# %%
res <- residuals(gg)

# %%
autoplot(res)
# Out:
# plot without title

# %%
tsdisplay(res)
# Out:
# Plot with title ""

# %%
mean(res, na.rm= TRUE)
# Out:
# [1] 6.834437

# %%
checkresiduals(res)
# Out:
# Warning message in modeldf.default(object):
# "Could not find appropriate degrees of freedom for this model."
# plot without title

# %% [markdown]
# The residuals are uncorrelated. If there are correlations between residuals, then there is information left in the residuals which should be used in computing forecasts.

# %% [markdown]
# The residuals have zero mean. If the residuals have a mean other than zero, then the forecasts are biased.

# %% [markdown]
# # 8.

# %%
retaildata <- readxl::read_excel("retail.xlsx", skip=1)

# %%
myts <- ts(retaildata[,"A3349873A"],
  frequency=12, start=c(1982,4))

# %%
myts.train <- window(myts, end=c(2010,12))
myts.test <- window(myts, start=2011)

# %%
autoplot(myts) +
  autolayer(myts.train, series="Training") +
  autolayer(myts.test, series="Test")
# Out:
# plot without title

# %%
fc <- snaive(myts.train)

# %%
autoplot(fc)
# Out:
# plot without title

# %%
accuracy(fc,myts.test)
# Out:
#              ME        RMSE     MAE      MPE       MAPE      MASE     ACF1
# Training set  7.772973 20.24576 15.95676  4.702754  8.109777 1.000000 0.7385090
# Test set     55.300000 71.44309 55.78333 14.900996 15.082019 3.495907 0.5315239
#              Theil's U
# Training set       NA
# Test set     1.297866

# %%
checkresiduals(fc)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Seasonal naive method
# Q* = 624.45, df = 24, p-value < 2.2e-16
#
# Model df: 0.   Total lags used: 24
# plot without title

# %% [markdown]
# # 9.

# %%
autoplot(visnights)
# Out:
# plot without title

# %%
visnights
# Out:
# ERROR while rich displaying an object: Error in repr_matrix_generic(obj, "\n%s%s\n", sprintf("|%%s\n|%s|\n", : formal argument "cols" matched by multiple actual arguments
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
# ...

# %%
train1 <- window(visnights[, "QLDMetro"], end = c(2015, 4))
test1  <- window(visnights[, "QLDMetro"], end = c(2016, 4))

# %%
train2 <- window(visnights[, "QLDMetro"], end = c(2014, 4))
test2  <- window(visnights[, "QLDMetro"], end = c(2015, 4))

# %%
train3 <- window(visnights[, "QLDMetro"], end = c(2013, 4))
test3  <- window(visnights[, "QLDMetro"], end = c(2014, 4))

# %%
fc1  <- snaive(train1, 4)

# %%
fc2  <- snaive(train2,4)

# %%
fc3  <- snaive(train3,4)

# %%
fc1
# Out:
#         Point Forecast     Lo 80    Hi 80    Lo 95    Hi 95
# 2016 Q1      11.568824 10.227959 12.90969 9.518149 13.61950
# 2016 Q2       9.337821  7.996956 10.67869 7.287146 11.38850
# 2016 Q3      10.740806  9.399941 12.08167 8.690130 12.79148
# 2016 Q4      10.300925  8.960060 11.64179 8.250250 12.35160

# %%
fc2
# Out:
#         Point Forecast     Lo 80    Hi 80    Lo 95    Hi 95
# 2015 Q1      11.460221 10.084401 12.83604 9.356085 13.56436
# 2015 Q2       9.786074  8.410254 11.16189 7.681939 11.89021
# 2015 Q3      10.058638  8.682818 11.43446 7.954503 12.16277
# 2015 Q4      10.315296  8.939476 11.69112 8.211161 12.41943

# %%
fc3
# Out:
#         Point Forecast     Lo 80     Hi 80     Lo 95     Hi 95
# 2014 Q1      12.156351 10.779267 13.533434 10.050283 14.262419
# 2014 Q2       7.891850  6.514766  9.268934  5.785782  9.997918
# 2014 Q3       9.486097  8.109013 10.863180  7.380029 11.592165
# 2014 Q4      10.602601  9.225518 11.979685  8.496533 12.708669

# %%
accuracy(fc1 ,test1 )
# Out:
#              ME         RMSE      MAE       MPE        MAPE     MASE
# Training set 0.02006107 1.0462821 0.8475553 -0.2237701 7.976760 1.0000000
# Test set     0.56983879 0.9358727 0.7094002  4.6191866 6.159821 0.8369957
#              ACF1       Theil's U
# Training set 0.06014484        NA
# Test set     0.09003153 0.4842061

# %%
accuracy(fc2 ,test2 )
# Out:
#              ME         RMSE      MAE       MPE        MAPE     MASE
# Training set 0.01618760 1.0735582 0.8809432 -0.2744747 8.284216 1.0000000
# Test set     0.08203656 0.4117902 0.3133488  0.5875037 3.057463 0.3556969
#              ACF1        Theil's U
# Training set  0.06610879        NA
# Test set     -0.59903247 0.3336559

# %%
accuracy(fc3 ,test3 )
# Out:
#              ME           RMSE     MAE       MPE        MAPE     MASE
# Training set -0.007455407 1.074544 0.8821694 -0.5625865 8.271365 1.0000000
# Test set      0.370832661 1.058658 0.8625501  4.0472032 8.476977 0.9777602
#              ACF1        Theil's U
# Training set  0.07317746       NA
# Test set     -0.36890062 1.177346

# %% [markdown]
# # 10.

# %%
tsdisplay(dowjones)
# Out:
# Plot with title ""

# %%
autoplot(dowjones)
# Out:
# plot without title

# %%
driftfc <- rwf(dowjones ,drift=TRUE)

# %%
autoplot(driftfc)
# Out:
# plot without title

# %%
dowjones[]
# Out:
# ERROR while rich displaying an object: Error in if (many_rows) {: argument is of length zero
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# ...

# %%
#example    

x1 <- stats::runif(5)
x2 <- stats::runif(5)+2
y <- stats::rnorm(10)


plot(c(x1,x2), y)


segments(x1, y[1:5], x2, y[6:10], col= 'blue')
# Out:
# plot without title

# %% [markdown]
# # 11.

# %%
ibmclose
# Out:
# ERROR while rich displaying an object: Error in if (many_rows) {: argument is of length zero
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# ...

# %%
autoplot(ibmclose)
# Out:
# plot without title

# %%
tsdisplay(ibmclose)
# Out:
# Plot with title ""

# %%
train <- window(ibmclose, end= 300 )
test  <- window(ibmclose, start = 301)

# %%
autoplot(test)
# Out:
# plot without title

# %%
length(train)
# Out:
# [1] 300

# %%
fc1 <- meanf(train, h=69)
 fc2<- naive(train, h=69)
 fc3<- snaive(train, h=69)
fc4 <- rwf(train, h=69, drift=TRUE)

# %%
autoplot(train) +
  autolayer(meanf(train, h=69),
    series="Mean", PI=FALSE) +
  autolayer(rwf(train, h=69),
    series="Naïve", PI=FALSE) +
  autolayer(rwf(train, drift=TRUE, h=69),
    series="Drift", PI=FALSE) +
  autolayer(test) +
  ggtitle("IBMCLOSE") +
  xlab("Day") + ylab("Closing Price (US$)") +
  guides(colour=guide_legend(title="Forecast"))
# Out:
# plot without title

# %%
accuracy(fc1, test)
# Out:
#              ME            RMSE      MAE       MPE        MAPE     MASE
# Training set  1.660438e-14  73.61532  58.72231  -2.642058 13.03019 11.52098
# Test set     -1.306180e+02 132.12557 130.61797 -35.478819 35.47882 25.62649
#              ACF1      Theil's U
# Training set 0.9895779       NA
# Test set     0.9314689 19.05515

# %%
accuracy(fc2, test)
# Out:
#              ME         RMSE      MAE      MPE         MAPE     MASE
# Training set -0.2809365  7.302815  5.09699 -0.08262872 1.115844 1.000000
# Test set     -3.7246377 20.248099 17.02899 -1.29391743 4.668186 3.340989
#              ACF1      Theil's U
# Training set 0.1351052       NA
# Test set     0.9314689 2.973486

# %%
accuracy(fc3, test)
# Out:
#              ME         RMSE      MAE      MPE         MAPE     MASE
# Training set -0.2809365  7.302815  5.09699 -0.08262872 1.115844 1.000000
# Test set     -3.7246377 20.248099 17.02899 -1.29391743 4.668186 3.340989
#              ACF1      Theil's U
# Training set 0.1351052       NA
# Test set     0.9314689 2.973486

# %%
accuracy(fc4, test)
# Out:
#              ME           RMSE      MAE       MPE         MAPE     MASE
# Training set 2.870480e-14  7.297409  5.127996 -0.02530123 1.121650 1.006083
# Test set     6.108138e+00 17.066963 13.974747  1.41920066 3.707888 2.741765
#              ACF1      Theil's U
# Training set 0.1351052       NA
# Test set     0.9045875 2.361092

# %%
accuracy(test, test)
# Out:
#          ME RMSE MAE MPE MAPE ACF1 Theil's U
# Test set 0  0    0   0   0    NaN  0

# %%
checkresiduals(fc4)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Random walk with drift
# Q* = 22.555, df = 9, p-value = 0.007278
#
# Model df: 1.   Total lags used: 10
# plot without title

# %% [markdown]
# # 12.

# %%
tsdisplay(hsales)
# Out:
# Plot with title ""

# %%
frequency(hsales)
# Out:
# [1] 12

# %%
tail(hsales, 12)
# Out:
# ERROR while rich displaying an object: Error in repr_matrix_generic(obj, "\n%s%s\n", sprintf("|%%s\n|%s|\n", : formal argument "cols" matched by multiple actual arguments
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
# ...

# %%
train  <- subset(hsales, end= length(hsales) - 12*2)
test   <- subset(hsales, start=length(hsales)+1 - 12*2)

# %%
length(train)
# Out:
# [1] 251

# %%
length(test)
# Out:
# [1] 24

# %%
length(hsales)
# Out:
# [1] 275

# %%
tsdisplay(train)
# Out:
# Plot with title ""

# %%
tsdisplay(test)
# Out:
# Plot with title ""

# %%
autoplot(train) +
  autolayer(meanf(train, h=24),
    series="Mean", PI=FALSE) +
  autolayer(rwf(train, h=24),
    series="Naïve", PI=FALSE) +
  autolayer(rwf(train, drift=TRUE, h=24),
    series="Drift", PI=FALSE) +
  autolayer(snaive(train , h=24),
    series="snaive", PI=FALSE) +
    
  autolayer(test) +
  ggtitle("IBMCLOSE") +
  xlab("Day") + ylab("Closing Price (US$)") +
  guides(colour=guide_legend(title="Forecast"))
# Out:
# plot without title

# %%
fc1 <- meanf(train, h=24)
 fc2<- naive(train, h=24)
 fc3<- snaive(train, h=24)
fc4 <- rwf(train, h=24, drift=TRUE)

# %%
accuracy(fc1, test)
# Out:
#              ME           RMSE      MAE      MPE       MAPE     MASE
# Training set 3.510503e-15 12.162811 9.532738 -6.144876 20.38306 1.1234341
# Test set     3.839475e+00  9.022555 7.561587  4.779122 13.26183 0.8911338
#              ACF1      Theil's U
# Training set 0.8661998       NA
# Test set     0.5377994 1.131713

# %%
accuracy(fc2, test)
# Out:
#              ME        RMSE     MAE      MPE       MAPE      MASE
# Training set -0.008000 6.301111 5.000000 -0.767457  9.903991 0.5892505
# Test set      2.791667 8.628924 7.208333  2.858639 12.849194 0.8495028
#              ACF1      Theil's U
# Training set 0.1824472       NA
# Test set     0.5377994 1.098358

# %%
accuracy(fc3, test)
# Out:
#              ME        RMSE      MAE      MPE       MAPE      MASE
# Training set 0.1004184 10.582214 8.485356 -2.184269 17.633696 1.0000000
# Test set     1.0416667  5.905506 4.791667  0.972025  8.545729 0.5646984
#              ACF1      Theil's U
# Training set 0.8369786        NA
# Test set     0.1687797 0.7091534

# %%
accuracy(fc4, test)
# Out:
#              ME           RMSE     MAE      MPE        MAPE      MASE
# Training set 1.506410e-15 6.301106 4.999872 -0.7511048  9.903063 0.5892354
# Test set     2.891667e+00 8.658795 7.249000  3.0426108 12.901697 0.8542954
#              ACF1      Theil's U
# Training set 0.1824472       NA
# Test set     0.5378711 1.100276

# %%
checkresiduals(fc3)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Seasonal naive method
# Q* = 682.2, df = 24, p-value < 2.2e-16
#
# Model df: 0.   Total lags used: 24
# plot without title
